# %%
import pandas as pd

# %%
# Read the data
df=pd.read_csv('daily_report_python (3).csv')

df
# Out:
#               Meeting ID                      Topic              Start Time  \
# 0            94260712307         BTEC Fall Training  11/08/2022 08:57:15 AM
# 1   Name (Original Name)                 User Email               Join Time
# 2           Boshra Jaber           b.jaber@ltuc.com  11/08/2022 08:57:15 AM
# 3     Mostafa Albelbeisi  20020480@student.ltuc.com  11/08/2022 08:57:34 AM
# 4    Mohannad Ghabashneh  22034356@student.ltuc.com  11/08/2022 08:57:35 AM
# ..                   ...                        ...                     ...
# 61            Tahani Ali                        NaN  11/08/2022 10:42:45 AM
# 62            Tahani Ali                        NaN  11/08/2022 10:46:22 AM
# 63           رزان عويضات                        NaN  11/08/2022 09:36:33 AM
# 64            Tahani Ali                        NaN  11/08/2022 10:44:22 AM
# 65           Walaa Atiyh                        NaN  11/08/2022 11:01:33 AM
#
#                   End Time          User Email Duration (Minutes)  \
# 0   11/08/2022 11:11:34 AM    b.Jaber@ltuc.com                135
# 1               Leave Time  Duration (Minutes)              Guest
# 2   11/08/2022 09:41:03 AM                  44                 No
# 3   11/08/2022 11:11:34 AM                 134                 No
# 4   11/08/2022 11:11:34 AM                 134                 No
# ..                     ...                 ...                ...
# 61  11/08/2022 10:44:21 AM                   2                Yes
# 62  11/08/2022 11:11:34 AM                  26                Yes
# 63  11/08/2022 09:37:59 AM                   2                Yes
# 64  11/08/2022 10:45:39 AM                   2                Yes
# 65  11/08/2022 11:11:34 AM                  11                Yes
#
#          Participants       Unnamed: 7
# 0                  64              NaN
# 1   Recording Consent  In Waiting Room
# 2                 NaN               No
# 3                 NaN               No
# 4                 NaN               No
# ..                ...              ...
# 61                NaN               No
# 62                NaN               No
# 63                NaN               No
# 64                NaN               No
# 65                NaN               No
#
# [66 rows x 8 columns]

# %%
# Divide the data and Preparing data
df1,df2=df[:1],df[1:]
df2.columns=df2.iloc[0]
df2.drop(df2.index[0],inplace=True)
df2
# Out:
# /tmp/ipykernel_1079/3765082423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(df2.index[0],inplace=True)
# 1  Name (Original Name)                 User Email               Join Time  \
# 2          Boshra Jaber           b.jaber@ltuc.com  11/08/2022 08:57:15 AM
# 3    Mostafa Albelbeisi  20020480@student.ltuc.com  11/08/2022 08:57:34 AM
# 4   Mohannad Ghabashneh  22034356@student.ltuc.com  11/08/2022 08:57:35 AM
# 5        Abdallah Mousa  22033848@student.ltuc.com  11/08/2022 08:58:00 AM
# 6          Ashar Momani                        NaN  11/08/2022 08:58:14 AM
# ..                  ...                        ...                     ...
# 61           Tahani Ali                        NaN  11/08/2022 10:42:45 AM
# 62           Tahani Ali                        NaN  11/08/2022 10:46:22 AM
# 63          رزان عويضات                        NaN  11/08/2022 09:36:33 AM
# 64           Tahani Ali                        NaN  11/08/2022 10:44:22 AM
# 65          Walaa Atiyh                        NaN  11/08/2022 11:01:33 AM
#
# 1               Leave Time Duration (Minutes) Guest Recording Consent  \
# 2   11/08/2022 09:41:03 AM                 44    No               NaN
# 3   11/08/2022 11:11:34 AM                134    No               NaN
# 4   11/08/2022 11:11:34 AM                134    No               NaN
# 5   11/08/2022 11:11:34 AM                134    No               NaN
# 6   11/08/2022 11:11:34 AM                134   Yes               Yes
# ..                     ...                ...   ...               ...
# 61  11/08/2022 10:44:21 AM                  2   Yes               NaN
# 62  11/08/2022 11:11:34 AM                 26   Yes               NaN
# 63  11/08/2022 09:37:59 AM                  2   Yes               NaN
# 64  11/08/2022 10:45:39 AM                  2   Yes               NaN
# 65  11/08/2022 11:11:34 AM                 11   Yes               NaN
#
# 1  In Waiting Room
# 2               No
# 3               No
# 4               No
# 5               No
# 6               No
# ..             ...
# 61              No
# 62              No
# 63              No
# 64              No
# 65              No
#
# [64 rows x 8 columns]

# %%
# Get students ID
df2['Students ID']=df2['User Email'].str.extract(pat=('(^\d*)'))
df2
# Out:
# /tmp/ipykernel_1079/3293854551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Students ID']=df2['User Email'].str.extract(pat=('(^\d*)'))
# 1  Name (Original Name)                 User Email               Join Time  \
# 2          Boshra Jaber           b.jaber@ltuc.com  11/08/2022 08:57:15 AM
# 3    Mostafa Albelbeisi  20020480@student.ltuc.com  11/08/2022 08:57:34 AM
# 4   Mohannad Ghabashneh  22034356@student.ltuc.com  11/08/2022 08:57:35 AM
# 5        Abdallah Mousa  22033848@student.ltuc.com  11/08/2022 08:58:00 AM
# 6          Ashar Momani                        NaN  11/08/2022 08:58:14 AM
# ..                  ...                        ...                     ...
# 61           Tahani Ali                        NaN  11/08/2022 10:42:45 AM
# 62           Tahani Ali                        NaN  11/08/2022 10:46:22 AM
# 63          رزان عويضات                        NaN  11/08/2022 09:36:33 AM
# 64           Tahani Ali                        NaN  11/08/2022 10:44:22 AM
# 65          Walaa Atiyh                        NaN  11/08/2022 11:01:33 AM
#
# 1               Leave Time Duration (Minutes) Guest Recording Consent  \
# 2   11/08/2022 09:41:03 AM                 44    No               NaN
# 3   11/08/2022 11:11:34 AM                134    No               NaN
# 4   11/08/2022 11:11:34 AM                134    No               NaN
# 5   11/08/2022 11:11:34 AM                134    No               NaN
# 6   11/08/2022 11:11:34 AM                134   Yes               Yes
# ..                     ...                ...   ...               ...
# 61  11/08/2022 10:44:21 AM                  2   Yes               NaN
# 62  11/08/2022 11:11:34 AM                 26   Yes               NaN
# 63  11/08/2022 09:37:59 AM                  2   Yes               NaN
# 64  11/08/2022 10:45:39 AM                  2   Yes               NaN
# 65  11/08/2022 11:11:34 AM                 11   Yes               NaN
#
# 1  In Waiting Room Students ID
# 2               No
# 3               No    20020480
# 4               No    22034356
# 5               No    22033848
# 6               No         NaN
# ..             ...         ...
# 61              No         NaN
# 62              No         NaN
# 63              No         NaN
# 64              No         NaN
# 65              No         NaN
#
# [64 rows x 9 columns]

# %%
df2["Total"]=df2['Duration (Minutes)'].astype('int')
# Out:
# /tmp/ipykernel_1079/198043095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Total"]=df2['Duration (Minutes)'].astype('int')

# %%
meeting_duration=int(df1['Duration (Minutes)'][0])
meeting_duration
# Out:
# 135

# %%
# Sum total of time for each student
df2=df2.groupby('Students ID',as_index=False).sum(numeric_only=True)
df2= df2[1:]
df2
# Out:
# 1  Students ID  Total
# 1     19012233    132
# 2     20019322    131
# 3     20019523    120
# 4     20020480    134
# 5     21023784    124
# 6     22032930    130
# 7     22033848    134
# 8     22034140    130
# 9     22034185    107
# 10    22034186    128
# 11    22034189    132
# 12    22034245    130
# 13    22034252    130
# 14    22034270    133
# 15    22034278    126
# 16    22034284    127
# 17    22034289    127
# 18    22034306    122
# 19    22034311    121
# 20    22034319    123
# 21    22034326    127
# 22    22034356    134
# 23    22034359    132
# 24    22034361    127
# 25    22034362     61
# 26    22034365    125
# 27    22034368    133
# 28    22034371    122

# %%
# Status:
df2['Status']=['Present'if x>=meeting_duration-10 else 'Absent' if x<meeting_duration-20 else 'Late' for x in df2['Total']]
df2['Percentage of attendance']=[f'{round((x/meeting_duration)*100)}%' for x in df2['Total']]
df2
# Out:
# 1  Students ID  Total   Status Percentage of attendance
# 1     19012233    132  Present                      98%
# 2     20019322    131  Present                      97%
# 3     20019523    120     Late                      89%
# 4     20020480    134  Present                      99%
# 5     21023784    124     Late                      92%
# 6     22032930    130  Present                      96%
# 7     22033848    134  Present                      99%
# 8     22034140    130  Present                      96%
# 9     22034185    107   Absent                      79%
# 10    22034186    128  Present                      95%
# 11    22034189    132  Present                      98%
# 12    22034245    130  Present                      96%
# 13    22034252    130  Present                      96%
# 14    22034270    133  Present                      99%
# 15    22034278    126  Present                      93%
# 16    22034284    127  Present                      94%
# 17    22034289    127  Present                      94%
# 18    22034306    122     Late                      90%
# 19    22034311    121     Late                      90%
# 20    22034319    123     Late                      91%
# 21    22034326    127  Present                      94%
# 22    22034356    134  Present                      99%
# 23    22034359    132  Present                      98%
# 24    22034361    127  Present                      94%
# 25    22034362     61   Absent                      45%
# 26    22034365    125  Present                      93%
# 27    22034368    133  Present                      99%
# 28    22034371    122     Late                      90%

# %%
meeting_id=df1['Meeting ID'][0]
meeting_id
# Out:
# '94260712307'

# %%
df3=pd.read_csv('./data.csv')
df3[meeting_id]=  df2["Status"]
df3["Student ID"] = df2["Student ID"]

df3.to_csv('./data.csv')
df3
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In [80], line 1
# ----> 1 df3=pd.read_csv('./data.csv')
#       2 df3[meeting_id]=  df2["Status"]
#       3 df3["Student ID"] = df2["Student ID"]
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1753, in TextFileReader._make_engine(self, f, engine)
#    1750     raise ValueError(msg)
#    1752 try:
# -> 1753     return mapping[engine](f, **self.options)
#    1754 except Exception:
#    1755     if self.handles is not None:
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:79, in CParserWrapper.__init__(self, src, **kwds)
#      76     kwds.pop(key, None)
#      78 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 79 self._reader = parsers.TextReader(src, **kwds)
#      81 self.unnamed_cols = self._reader.unnamed_cols
#      83 # error: Cannot determine type of 'names'
#
# File ~/a/.venv/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:554, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file
